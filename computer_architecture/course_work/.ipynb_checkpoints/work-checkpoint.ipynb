# %% [markdown]
# # Курсовая работа
#
# #### Применение вариационного автоэнкодера (VAE) для кодирования изображения и последующего восстановления с минимальными потерями качества

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.layers import Dense, Flatten, Reshape, Input, InputLayer
from keras.models import Sequential, Model
from sklearn.model_selection import train_test_split
import cv2

from typing import List, Any
# %matplotlib widget
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preprocessing

# %%
os.chdir("/Users/akira/Documents/projects/polytech-study/computer_architecture/course_work")

data_dir = './data/pokemons/gen5'
output_dir = './output'

# %%
data_dirs = './data/pokemons/'
sub_dirs = [
    os.path.join(data_dirs, folder) 
    for folder in os.listdir(data_dirs) 
    if '.ipynb' not in folder and '.DS_Store' not in folder
]

filenames_paths = []
for sub_dir in sub_dirs:
    dir_paths = [
        os.path.join(sub_dir, file_name)
        for file_name in os.listdir(sub_dir)
        if '.png' in file_name
    ]
    filenames_paths.extend(dir_paths)
# Out:
# ['./data/pokemons/gen4/566.png',
#  './data/pokemons/gen4/572.png',
#  './data/pokemons/gen4/573.png',
#  './data/pokemons/gen4/567.png',
#  './data/pokemons/gen4/559.png',
#  './data/pokemons/gen4/571.png',
#  './data/pokemons/gen4/565.png',
#  './data/pokemons/gen4/564.png',
#  './data/pokemons/gen4/570.png',
#  './data/pokemons/gen4/558.png',
#  './data/pokemons/gen4/574.png',
#  './data/pokemons/gen4/560.png',
#  './data/pokemons/gen4/561.png',
#  './data/pokemons/gen4/575.png',
#  './data/pokemons/gen4/563.png',
#  './data/pokemons/gen4/577.png',
#  './data/pokemons/gen4/576.png',
#  './data/pokemons/gen4/562.png',
#  './data/pokemons/gen4/459.png',
#  './data/pokemons/gen4/471.png',
#  './data/pokemons/gen4/465.png',
#  './data/pokemons/gen4/539.png',
#  './data/pokemons/gen4/505.png',
#  './data/pokemons/gen4/511.png',
#  './data/pokemons/gen4/510.png',
#  './data/pokemons/gen4/504.png',
#  './data/pokemons/gen4/538.png',
#  './data/pokemons/gen4/464.png',
#  './data/pokemons/gen4/470.png',
#  './data/pokemons/gen4/458.png',
#  './data/pokemons/gen4/466.png',
#  './data/pokemons/gen4/472.png',
#  './data/pokemons/gen4/499.png',
#  './data/pokemons/gen4/512.png',
#  './data/pokemons/gen4/506.png',
#  './data/pokemons/gen4/507.png',
#  './data/pokemons/gen4/513.png',
#  './data/pokemons/gen4/498.png',
#  './data/pokemons/gen4/473.png',
#  './data/pokemons/gen4/467.png',
#  './data/pokemons/gen4/463.png',
#  './data/pokemons/gen4/477.png',
#  './data/pokemons/gen4/488.png',
#  './data/pokemons/gen4/517.png',
#  './data/pokemons/gen4/503.png',
#  './data/pokemons/gen4/502.png',
#  './data/pokemons/gen4/516.png',
#  './data/pokemons/gen4/489.png',
#  './data/pokemons/gen4/476.png',
#  './data/pokemons/gen4/462.png',
#  './data/pokemons/gen4/474.png',
#  './data/pokemons/gen4/460.png',
#  './data/pokemons/gen4/448.png',
#  './data/pokemons/gen4/500.png',
#  './data/pokemons/gen4/514.png',
#  './data/pokemons/gen4/528.png',
#  './data/pokemons/gen4/529.png',
#  './data/pokemons/gen4/515.png',
#  './data/pokemons/gen4/501.png',
#  './data/pokemons/gen4/449.png',
#  './data/pokemons/gen4/461.png',
#  './data/pokemons/gen4/475.png',
#  './data/pokemons/gen4/478.png',
#  './data/pokemons/gen4/450.png',
#  './data/pokemons/gen4/444.png',
#  './data/pokemons/gen4/493.png',
#  './data/pokemons/gen4/487.png',
#  './data/pokemons/gen4/518.png',
#  './data/pokemons/gen4/524.png',
#  './data/pokemons/gen4/530.png',
#  './data/pokemons/gen4/531.png',
#  './data/pokemons/gen4/525.png',
#  './data/pokemons/gen4/519.png',
#  './data/pokemons/gen4/486.png',
#  './data/pokemons/gen4/492.png',
#  './data/pokemons/gen4/445.png',
#  './data/pokemons/gen4/451.png',
#  './data/pokemons/gen4/479.png',
#  './data/pokemons/gen4/447.png',
#  './data/pokemons/gen4/453.png',
#  './data/pokemons/gen4/484.png',
#  './data/pokemons/gen4/490.png',
#  './data/pokemons/gen4/533.png',
#  './data/pokemons/gen4/527.png',
#  './data/pokemons/gen4/526.png',
#  './data/pokemons/gen4/532.png',
#  './data/pokemons/gen4/491.png',
#  './data/pokemons/gen4/485.png',
#  './data/pokemons/gen4/452.png',
#  './data/pokemons/gen4/446.png',
#  './data/pokemons/gen4/442.png',
#  './data/pokemons/gen4/456.png',
#  './data/pokemons/gen4/481.png',
#  './data/pokemons/gen4/495.png',
#  './data/pokemons/gen4/536.png',
#  './data/pokemons/gen4/522.png',
#  './data/pokemons/gen4/523.png',
#  './data/pokemons/gen4/537.png',
#  './data/pokemons/gen4/494.png',
#  './data/pokemons/gen4/480.png',
#  './data/pokemons/gen4/457.png',
#  './data/pokemons/gen4/443.png',
#  './data/pokemons/gen4/455.png',
#  './data/pokemons/gen4/441.png',
#  './data/pokemons/gen4/469.png',
#  './data/pokemons/gen4/496.png',
#  './data/pokemons/gen4/482.png',
#  './data/pokemons/gen4/521.png',
#  './data/pokemons/gen4/535.png',
#  './data/pokemons/gen4/509.png',
#  './data/pokemons/gen4/508.png',
#  './data/pokemons/gen4/534.png',
#  './data/pokemons/gen4/520.png',
#  './data/pokemons/gen4/483.png',
#  './data/pokemons/gen4/497.png',
#  './data/pokemons/gen4/468.png',
#  './data/pokemons/gen4/440.png',
#  './data/pokemons/gen4/454.png',
#  './data/pokemons/gen4/553.png',
#  './data/pokemons/gen4/546.png',
#  './data/pokemons/gen4/578.png',
#  './data/pokemons/gen4/544.png',
#  './data/pokemons/gen4/545.png',
#  './data/pokemons/gen4/579.png',
#  './data/pokemons/gen4/555.png',
#  './data/pokemons/gen4/541.png',
#  './data/pokemons/gen4/569.png',
#  './data/pokemons/gen4/582.png',
#  './data/pokemons/gen4/568.png',
#  './data/pokemons/gen4/540.png',
#  './data/pokemons/gen4/554.png',
#  './data/pokemons/gen4/542.png',
#  './data/pokemons/gen4/556.png',
#  './data/pokemons/gen4/581.png',
#  './data/pokemons/gen4/580.png',
#  './data/pokemons/gen4/557.png',
#  './data/pokemons/gen4/543.png',
#  './data/pokemons/gen3/348.png',
#  './data/pokemons/gen3/374.png',
#  './data/pokemons/gen3/360.png',
#  './data/pokemons/gen3/406.png',
#  './data/pokemons/gen3/361.png',
#  './data/pokemons/gen3/407.png',
#  './data/pokemons/gen3/375.png',
#  './data/pokemons/gen3/349.png',
#  './data/pokemons/gen3/405.png',
#  './data/pokemons/gen3/363.png',
#  './data/pokemons/gen3/377.png',
#  './data/pokemons/gen3/411.png',
#  './data/pokemons/gen3/388.png',
#  './data/pokemons/gen3/389.png',
#  './data/pokemons/gen3/376.png',
#  './data/pokemons/gen3/410.png',
#  './data/pokemons/gen3/404.png',
#  './data/pokemons/gen3/362.png',
#  './data/pokemons/gen3/366.png',
#  './data/pokemons/gen3/400.png',
#  './data/pokemons/gen3/372.png',
#  './data/pokemons/gen3/399.png',
#  './data/pokemons/gen3/398.png',
#  './data/pokemons/gen3/373.png',
#  './data/pokemons/gen3/367.png',
#  './data/pokemons/gen3/401.png',
#  './data/pokemons/gen3/371.png',
#  './data/pokemons/gen3/403.png',
#  './data/pokemons/gen3/365.png',
#  './data/pokemons/gen3/359.png',
#  './data/pokemons/gen3/358.png',
#  './data/pokemons/gen3/402.png',
#  './data/pokemons/gen3/364.png',
#  './data/pokemons/gen3/370.png',
#  './data/pokemons/gen3/317.png',
#  './data/pokemons/gen3/303.png',
#  './data/pokemons/gen3/277.png',
#  './data/pokemons/gen3/288.png',
#  './data/pokemons/gen3/289.png',
#  './data/pokemons/gen3/706.png',
#  './data/pokemons/gen3/302.png',
#  './data/pokemons/gen3/316.png',
#  './data/pokemons/gen3/328.png',
#  './data/pokemons/gen3/300.png',
#  './data/pokemons/gen3/314.png',
#  './data/pokemons/gen3/704.png',
#  './data/pokemons/gen3/705.png',
#  './data/pokemons/gen3/315.png',
#  './data/pokemons/gen3/301.png',
#  './data/pokemons/gen3/329.png',
#  './data/pokemons/gen3/305.png',
#  './data/pokemons/gen3/311.png',
#  './data/pokemons/gen3/339.png',
#  './data/pokemons/gen3/338.png',
#  './data/pokemons/gen3/310.png',
#  './data/pokemons/gen3/304.png',
#  './data/pokemons/gen3/312.png',
#  './data/pokemons/gen3/306.png',
#  './data/pokemons/gen3/299.png',
#  './data/pokemons/gen3/298.png',
#  './data/pokemons/gen3/307.png',
#  './data/pokemons/gen3/313.png',
#  './data/pokemons/gen3/336.png',
#  './data/pokemons/gen3/322.png',
#  './data/pokemons/gen3/281.png',
#  './data/pokemons/gen3/295.png',
#  './data/pokemons/gen3/294.png',
#  './data/pokemons/gen3/280.png',
#  './data/pokemons/gen3/323.png',
#  './data/pokemons/gen3/337.png',
#  './data/pokemons/gen3/309.png',
#  './data/pokemons/gen3/321.png',
#  './data/pokemons/gen3/335.png',
#  './data/pokemons/gen3/296.png',
#  './data/pokemons/gen3/282.png',
#  './data/pokemons/gen3/283.png',
#  './data/pokemons/gen3/297.png',
#  './data/pokemons/gen3/334.png',
#  './data/pokemons/gen3/320.png',
#  './data/pokemons/gen3/308.png',
#  './data/pokemons/gen3/324.png',
#  './data/pokemons/gen3/330.png',
#  './data/pokemons/gen3/318.png',
#  './data/pokemons/gen3/278.png',
#  './data/pokemons/gen3/293.png',
#  './data/pokemons/gen3/287.png',
#  './data/pokemons/gen3/286.png',
#  './data/pokemons/gen3/292.png',
#  './data/pokemons/gen3/279.png',
#  './data/pokemons/gen3/319.png',
#  './data/pokemons/gen3/331.png',
#  './data/pokemons/gen3/325.png',
#  './data/pokemons/gen3/333.png',
#  './data/pokemons/gen3/327.png',
#  './data/pokemons/gen3/284.png',
#  './data/pokemons/gen3/290.png',
#  './data/pokemons/gen3/291.png',
#  './data/pokemons/gen3/285.png',
#  './data/pokemons/gen3/326.png',
#  './data/pokemons/gen3/332.png',
#  './data/pokemons/gen3/369.png',
#  './data/pokemons/gen3/355.png',
#  './data/pokemons/gen3/341.png',
#  './data/pokemons/gen3/396.png',
#  './data/pokemons/gen3/382.png',
#  './data/pokemons/gen3/383.png',
#  './data/pokemons/gen3/397.png',
#  './data/pokemons/gen3/340.png',
#  './data/pokemons/gen3/354.png',
#  './data/pokemons/gen3/368.png',
#  './data/pokemons/gen3/342.png',
#  './data/pokemons/gen3/356.png',
#  './data/pokemons/gen3/381.png',
#  './data/pokemons/gen3/395.png',
#  './data/pokemons/gen3/394.png',
#  './data/pokemons/gen3/380.png',
#  './data/pokemons/gen3/357.png',
#  './data/pokemons/gen3/343.png',
#  './data/pokemons/gen3/347.png',
#  './data/pokemons/gen3/353.png',
#  './data/pokemons/gen3/409.png',
#  './data/pokemons/gen3/384.png',
#  './data/pokemons/gen3/390.png',
#  './data/pokemons/gen3/391.png',
#  './data/pokemons/gen3/385.png',
#  './data/pokemons/gen3/408.png',
#  './data/pokemons/gen3/352.png',
#  './data/pokemons/gen3/346.png',
#  './data/pokemons/gen3/350.png',
#  './data/pokemons/gen3/344.png',
#  './data/pokemons/gen3/378.png',
#  './data/pokemons/gen3/393.png',
#  './data/pokemons/gen3/387.png',
#  './data/pokemons/gen3/386.png',
#  './data/pokemons/gen3/392.png',
#  './data/pokemons/gen3/379.png',
#  './data/pokemons/gen3/345.png',
#  './data/pokemons/gen3/351.png',
#  './data/pokemons/gen2/176.png',
#  './data/pokemons/gen2/162.png',
#  './data/pokemons/gen2/189.png',
#  './data/pokemons/gen2/228.png',
#  './data/pokemons/gen2/200.png',
#  './data/pokemons/gen2/214.png',
#  './data/pokemons/gen2/215.png',
#  './data/pokemons/gen2/229.png',
#  './data/pokemons/gen2/188.png',
#  './data/pokemons/gen2/163.png',
#  './data/pokemons/gen2/177.png',
#  './data/pokemons/gen2/161.png',
#  './data/pokemons/gen2/175.png',
#  './data/pokemons/gen2/217.png',
#  './data/pokemons/gen2/203.png',
#  './data/pokemons/gen2/202.png',
#  './data/pokemons/gen2/216.png',
#  './data/pokemons/gen2/174.png',
#  './data/pokemons/gen2/160.png',
#  './data/pokemons/gen2/164.png',
#  './data/pokemons/gen2/170.png',
#  './data/pokemons/gen2/158.png',
#  './data/pokemons/gen2/212.png',
#  './data/pokemons/gen2/206.png',
#  './data/pokemons/gen2/207.png',
#  './data/pokemons/gen2/213.png',
#  './data/pokemons/gen2/159.png',
#  './data/pokemons/gen2/171.png',
#  './data/pokemons/gen2/165.png',
#  './data/pokemons/gen2/173.png',
#  './data/pokemons/gen2/167.png',
#  './data/pokemons/gen2/198.png',
#  './data/pokemons/gen2/205.png',
#  './data/pokemons/gen2/211.png',
#  './data/pokemons/gen2/239.png',
#  './data/pokemons/gen2/238.png',
#  './data/pokemons/gen2/210.png',
#  './data/pokemons/gen2/204.png',
#  './data/pokemons/gen2/199.png',
#  './data/pokemons/gen2/166.png',
#  './data/pokemons/gen2/172.png',
#  './data/pokemons/gen2/248.png',
#  './data/pokemons/gen2/249.png',
#  './data/pokemons/gen2/242.png',
#  './data/pokemons/gen2/243.png',
#  './data/pokemons/gen2/241.png',
#  './data/pokemons/gen2/240.png',
#  './data/pokemons/gen2/250.png',
#  './data/pokemons/gen2/244.png',
#  './data/pokemons/gen2/245.png',
#  './data/pokemons/gen2/251.png',
#  './data/pokemons/gen2/247.png',
#  './data/pokemons/gen2/246.png',
#  './data/pokemons/gen2/157.png',
#  './data/pokemons/gen2/194.png',
#  './data/pokemons/gen2/180.png',
#  './data/pokemons/gen2/209.png',
#  './data/pokemons/gen2/221.png',
#  './data/pokemons/gen2/235.png',
#  './data/pokemons/gen2/234.png',
#  './data/pokemons/gen2/220.png',
#  './data/pokemons/gen2/208.png',
#  './data/pokemons/gen2/181.png',
#  './data/pokemons/gen2/195.png',
#  './data/pokemons/gen2/156.png',
#  './data/pokemons/gen2/168.png',
#  './data/pokemons/gen2/154.png',
#  './data/pokemons/gen2/183.png',
#  './data/pokemons/gen2/197.png',
#  './data/pokemons/gen2/236.png',
#  './data/pokemons/gen2/222.png',
#  './data/pokemons/gen2/223.png',
#  './data/pokemons/gen2/237.png',
#  './data/pokemons/gen2/196.png',
#  './data/pokemons/gen2/182.png',
#  './data/pokemons/gen2/155.png',
#  './data/pokemons/gen2/169.png',
#  './data/pokemons/gen2/179.png',
#  './data/pokemons/gen2/186.png',
#  './data/pokemons/gen2/192.png',
#  './data/pokemons/gen2/233.png',
#  './data/pokemons/gen2/227.png',
#  './data/pokemons/gen2/226.png',
#  './data/pokemons/gen2/232.png',
#  './data/pokemons/gen2/193.png',
#  './data/pokemons/gen2/187.png',
#  './data/pokemons/gen2/178.png',
#  './data/pokemons/gen2/152.png',
#  './data/pokemons/gen2/191.png',
#  './data/pokemons/gen2/185.png',
#  './data/pokemons/gen2/224.png',
#  './data/pokemons/gen2/230.png',
#  './data/pokemons/gen2/218.png',
#  './data/pokemons/gen2/219.png',
#  './data/pokemons/gen2/231.png',
#  './data/pokemons/gen2/225.png',
#  './data/pokemons/gen2/184.png',
#  './data/pokemons/gen2/190.png',
#  './data/pokemons/gen2/153.png',
#  './data/pokemons/gen5/638.png',
#  './data/pokemons/gen5/610.png',
#  './data/pokemons/gen5/604.png',
#  './data/pokemons/gen5/566.png',
#  './data/pokemons/gen5/572.png',
#  './data/pokemons/gen5/599.png',
#  './data/pokemons/gen5/745-alt.png',
#  './data/pokemons/gen5/598.png',
#  './data/pokemons/gen5/573.png',
#  './data/pokemons/gen5/567.png',
#  './data/pokemons/gen5/605.png',
#  './data/pokemons/gen5/611.png',
#  './data/pokemons/gen5/639.png',
#  './data/pokemons/gen5/607.png',
#  './data/pokemons/gen5/613.png',
#  './data/pokemons/gen5/559.png',
#  './data/pokemons/gen5/571.png',
#  './data/pokemons/gen5/565.png',
#  './data/pokemons/gen5/564.png',
#  './data/pokemons/gen5/570.png',
#  './data/pokemons/gen5/558.png',
#  './data/pokemons/gen5/612.png',
#  './data/pokemons/gen5/606.png',
#  './data/pokemons/gen5/602.png',
#  './data/pokemons/gen5/616.png',
#  './data/pokemons/gen5/574.png',
#  './data/pokemons/gen5/560.png',
#  './data/pokemons/gen5/548.png',
#  './data/pokemons/gen5/549.png',
#  './data/pokemons/gen5/561.png',
#  './data/pokemons/gen5/575.png',
#  './data/pokemons/gen5/617.png',
#  './data/pokemons/gen5/603.png',
#  './data/pokemons/gen5/615.png',
#  './data/pokemons/gen5/601.png',
#  './data/pokemons/gen5/629.png',
#  './data/pokemons/gen5/749.png',
#  './data/pokemons/gen5/563.png',
#  './data/pokemons/gen5/577.png',
#  './data/pokemons/gen5/588.png',
#  './data/pokemons/gen5/589.png',
#  './data/pokemons/gen5/576.png',
#  './data/pokemons/gen5/562.png',
#  './data/pokemons/gen5/744-alt.png',
#  './data/pokemons/gen5/748.png',
#  './data/pokemons/gen5/628.png',
#  './data/pokemons/gen5/600.png',
#  './data/pokemons/gen5/614.png',
#  './data/pokemons/gen5/673.png',
#  './data/pokemons/gen5/667.png',
#  './data/pokemons/gen5/698.png',
#  './data/pokemons/gen5/699.png',
#  './data/pokemons/gen5/666.png',
#  './data/pokemons/gen5/672.png',
#  './data/pokemons/gen5/658.png',
#  './data/pokemons/gen5/664.png',
#  './data/pokemons/gen5/670.png',
#  './data/pokemons/gen5/738.png',
#  './data/pokemons/gen5/739.png',
#  './data/pokemons/gen5/697-alt.png',
#  './data/pokemons/gen5/671.png',
#  './data/pokemons/gen5/665.png',
#  './data/pokemons/gen5/659.png',
#  './data/pokemons/gen5/661.png',
#  './data/pokemons/gen5/675.png',
#  './data/pokemons/gen5/649.png',
#  './data/pokemons/gen5/701.png',
#  './data/pokemons/gen5/700.png',
#  './data/pokemons/gen5/648.png',
#  './data/pokemons/gen5/674.png',
#  './data/pokemons/gen5/660.png',
#  './data/pokemons/gen5/696-alt.png',
#  './data/pokemons/gen5/676.png',
#  './data/pokemons/gen5/662.png',
#  './data/pokemons/gen5/689.png',
#  './data/pokemons/gen5/702.png',
#  './data/pokemons/gen5/688.png',
#  './data/pokemons/gen5/663.png',
#  './data/pokemons/gen5/677.png',
#  './data/pokemons/gen5/652.png',
#  './data/pokemons/gen5/646.png',
#  './data/pokemons/gen5/691.png',
#  './data/pokemons/gen5/685.png',
#  './data/pokemons/gen5/684.png',
#  './data/pokemons/gen5/690.png',
#  './data/pokemons/gen5/647.png',
#  './data/pokemons/gen5/653.png',
#  './data/pokemons/gen5/679.png',
#  './data/pokemons/gen5/645.png',
#  './data/pokemons/gen5/651.png',
#  './data/pokemons/gen5/686.png',
#  './data/pokemons/gen5/692.png',
#  './data/pokemons/gen5/693.png',
#  './data/pokemons/gen5/687.png',
#  './data/pokemons/gen5/650.png',
#  './data/pokemons/gen5/644.png',
#  './data/pokemons/gen5/678.png',
#  './data/pokemons/gen5/640.png',
#  './data/pokemons/gen5/654.png',
#  './data/pokemons/gen5/668.png',
#  './data/pokemons/gen5/683.png',
#  './data/pokemons/gen5/697.png',
#  './data/pokemons/gen5/696.png',
#  './data/pokemons/gen5/682.png',
#  './data/pokemons/gen5/669.png',
#  './data/pokemons/gen5/655.png',
#  './data/pokemons/gen5/641.png',
#  './data/pokemons/gen5/657.png',
#  './data/pokemons/gen5/643.png',
#  './data/pokemons/gen5/694.png',
#  './data/pokemons/gen5/680.png',
#  './data/pokemons/gen5/737.png',
#  './data/pokemons/gen5/736.png',
#  './data/pokemons/gen5/681.png',
#  './data/pokemons/gen5/695.png',
#  './data/pokemons/gen5/642.png',
#  './data/pokemons/gen5/656.png',
#  './data/pokemons/gen5/619.png',
#  './data/pokemons/gen5/631.png',
#  './data/pokemons/gen5/625.png',
#  './data/pokemons/gen5/745.png',
#  './data/pokemons/gen5/547.png',
#  './data/pokemons/gen5/553.png',
#  './data/pokemons/gen5/584.png',
#  './data/pokemons/gen5/590.png',
#  './data/pokemons/gen5/591.png']

# %%
def crop_imgs(paths: List[str], x:int, y:int, width:int, height:int, color_type_changer=None) -> List[Any]:
    """
    Обрезка изображений в формат 64х64 пикселя
    
    paths - пути к изображениям
    x, y - начальные координаты коориднаты для обрезания
    width, height - конечные коориднаты для обрезания
    color_type_changer - при необходимости перекодировка каналов цвета
    
    return - изображения ввиде numpy.ndarray
    """
    imgs = []
    for f_path in paths:
        img = cv2.imread(f_path)
        if color_type_changer:
            img = cv2.cvtColor(img, color_type_changer)
        imgs.append(img[x:x+width, y:y+height])
    return imgs

# %%
imgs = crop_imgs(filenames_paths, 0, 0, 64, 64, cv2.COLOR_BGR2RGB)
imgs = np.array(imgs)
imgs.shape
# Out:
# (704, 64, 64, 3)

# %%
plt.imshow(imgs[1])
plt.title("64x64 pixels. 3 channel RGB")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def img_table(imgs: np.ndarray, path=None):
    """
    Создание таблицы из всех изображений с границей в 1 пиксел.
    RGB коды в формате 0-255
    
    imgs - массив изображений
    path: str - путь для сохранения картинки в формате png
    """
    img_h, img_w = imgs.shape[1:3]
    n_plots = int(np.ceil(np.sqrt(imgs.shape[0])))
    table = np.ones(
        (imgs.shape[1] * n_plots + n_plots + 1,
        imgs.shape[2] * n_plots + n_plots + 1,
        3))
    for i in range(n_plots):
        for j in range(n_plots):
            idx = i * n_plots + j
            if idx < imgs.shape[0]:
                img = imgs[idx]
                table[1 + i + i * img_h:1 + i + (i + 1) * img_h,
                  1 + j + j * img_w:1 + j + (j + 1) * img_w] = img
    table = table.astype(np.uint8)
    if path:
        plt.imsave(arr=table, fname=path)
    return table

# %%
fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(img_table(imgs[:64]))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def normalization_0_1(imgs: np.ndarray) -> np.ndarray:
    """
    Нормализация кодов цветов от 0-255 к 0-1
    """
    return imgs.astype('float32') / 255.0 - 0.5

def normalization_0_255(imgs: np.ndarray) -> np.ndarray:
    """
    Нормализация кодов цветов от 0-1 к 0-255
    """
    return ((normal_imgs + 0.5) * 255).astype(np.uint8)

# %% [markdown]
# ## Создание модели энкодера и декодера

# %%
normal_imgs = normalization_0_1(imgs)
X_train, X_test = train_test_split(normal_imgs, test_size=0.1, random_state=42)

# %%
def build_autoencoder(img_shape, code_size):
    # The encoder
    encoder = Sequential()
    encoder.add(InputLayer(img_shape))
    encoder.add(Flatten())
    encoder.add(Dense(code_size))

    # The decoder
    decoder = Sequential()
    decoder.add(InputLayer((code_size,)))
    decoder.add(Dense(np.prod(img_shape))) # np.prod(img_shape) is the same as 32*32*3, it's more generic than saying 3072
    decoder.add(Reshape(img_shape))

    return encoder, decoder

# %%
# Same as (64,64,3), we neglect the number of instances from shape
IMG_SHAPE = normal_imgs.shape[1:]
encoder, decoder = build_autoencoder(IMG_SHAPE, 256)

inp = Input(IMG_SHAPE)
code = encoder(inp)
reconstruction = decoder(code)

autoencoder = Model(inp,reconstruction)
autoencoder.compile(optimizer='adamax', loss='mse')

print(autoencoder.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 256)               3145984
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 64, 64, 3)         3158016
# =================================================================
# Total params: 6,304,000
# Trainable params: 6,304,000
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = autoencoder.fit(x=X_train, y=X_train, epochs=20,
                validation_data=[X_test, X_test])
# Out:
# Train on 633 samples, validate on 71 samples
# Epoch 1/20
# 633/633 [==============================] - 3s 4ms/step - loss: 0.1060 - val_loss: 0.0539
# Epoch 2/20
# 633/633 [==============================] - 2s 4ms/step - loss: 0.0503 - val_loss: 0.0431
# Epoch 3/20
# 633/633 [==============================] - 2s 4ms/step - loss: 0.0418 - val_loss: 0.0399
# Epoch 4/20
# 633/633 [==============================] - 3s 4ms/step - loss: 0.0383 - val_loss: 0.0381
# Epoch 5/20
# 633/633 [==============================] - 3s 5ms/step - loss: 0.0366 - val_loss: 0.0370
# Epoch 6/20
# 633/633 [==============================] - 3s 4ms/step - loss: 0.0355 - val_loss: 0.0361
# Epoch 7/20
# 633/633 [==============================] - 2s 4ms/step - loss: 0.0346 - val_loss: 0.0353
# Epoch 8/20
#  64/633 [==>...........................] - ETA: 2s - loss: 0.0346

# %%
def show_image(x):
    plt.imshow(np.clip(x + 0.5, 0, 1))

def visualize(img,encoder,decoder):
    """Draws original, encoded and decoded images"""
    # img[None] will have shape of (1, 32, 32, 3) which is the same as the model input
    code = encoder.predict(img[None])[0]
    reco = decoder.predict(code[None])[0]

    plt.subplot(1,3,1)
    plt.title("Original")
    show_image(img)

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.reshape([code.shape[-1]//2,-1]))
    
    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    show_image(reco)
    plt.show()

for i in range(27):
    img = X_test[i]
    visualize(img,encoder,decoder)
